# %%
import json
with open("data.json") as f:
    data = json.load(f)
    print("")
    for line in json.dumps(data, indent=4, separators= (".", "=")):
        print(line)
# Out:
# {
#
#
#
#
#
#
# "
# t
# o
# t
# a
# l
# C
# o
# u
# n
# t
# "
# =
# "
# 4
# 0
# 0
# "
# .
#
#
#
#
#
#
# "
# i
# m
# d
# a
# t
# a
# "
# =
# [
#
#
#
#
#
#
#
#
#
#
# {
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# "
# l
# 1
# P
# h
# y
# s
# I
# f
# "
# =
# {
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# "
# a
# t
# t
# r
# i
# b
# u
# t
# e
# s
# "
# =
# {
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# "
# a
# d
# m
# i
# n
# S
# t
# "
# =
# "
# u
# p
# "
# .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# "
# a
# u
# t
# o
# N
# e
# g
# "
# =
# "
# o
# n
# "
# .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# "
# b
# r
# k
# o
# u
# t
# M
# a
# p
# "
# =
# "
# n
# o
# n
# e
# "
# .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# "
# b
# w
# "
# =
# "
# 0
# "
# .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# "
# c
# h
# i
# l
# d
# A
# c
# t
# i
# o
# n
# "
# =
# "
# "
# .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# "
# d
# e
# l
# a
# y
# "
# =
# "
# 1
# "
# .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# "
# d
# ...
